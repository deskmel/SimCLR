# %% [markdown]
# <a href="https://colab.research.google.com/github/sthalles/SimCLR/blob/master/feature_eval/linear_feature_eval.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gdown
# Out:
# Collecting gdown
#   Downloading https://files.pythonhosted.org/packages/db/f9/757abd4b0ebf60f3d276b599046c515c070fab5161b22abb952e35f3c0a4/gdown-3.11.0.tar.gz
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: requests[socks] in /data2/wm/anaconda3/lib/python3.7/site-packages (from gdown) (2.22.0)
# Requirement already satisfied: filelock in /data2/wm/anaconda3/lib/python3.7/site-packages (from gdown) (3.0.12)
# Requirement already satisfied: six in /data2/wm/anaconda3/lib/python3.7/site-packages (from gdown) (1.12.0)
# Requirement already satisfied: tqdm in /data2/wm/anaconda3/lib/python3.7/site-packages (from gdown) (4.36.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /data2/wm/anaconda3/lib/python3.7/site-packages (from requests[socks]->gdown) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /data2/wm/anaconda3/lib/python3.7/site-packages (from requests[socks]->gdown) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /data2/wm/anaconda3/lib/python3.7/site-packages (from requests[socks]->gdown) (1.24.2)
# Requirement already satisfied: certifi>=2017.4.17 in /data2/wm/anaconda3/lib/python3.7/site-packages (from requests[socks]->gdown) (2019.9.11)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in /data2/wm/anaconda3/lib/python3.7/site-packages (from requests[socks]->gdown) (1.7.1)
# Building wheels for collected packages: gdown
#   Building wheel for gdown (PEP 517) ... done
#   Created wheel for gdown: filename=gdown-3.11.0-cp37-none-any.whl size=9619 sha256=c382ee7ea0e5b2747c8f50eb4e69e3676a5619f26fdc34ed3fa69e57f9e4c216
#   Stored in directory: /home/meng/.cache/pip/wheels/19/a6/67/ebb80360fc57bb0ddd5da77f57b275084cd8838bf7d5b91685
# Successfully built gdown
# Installing collected packages: gdown
# Successfully installed gdown-3.11.0

# %%
folder_name = 'resnet-18_80-epochs'

# !gdown https://drive.google.com/uc?id=1c4eVon0sUd-ChVhH6XMpF6nCngNJsAPk # ResNet 18 --> 40 epochs trained
# !gdown https://drive.google.com/uc?id=1L0yoeY9i2mzDcj69P4slTWb-cfr3PyoT # ResNet 18 --> 80 epochs trained
# !unzip resnet-18_80-epochs
# !ls
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1L0yoeY9i2mzDcj69P4slTWb-cfr3PyoT
# To: /content/resnet-18_80-epochs.zip
# 43.3MB [00:00, 93.1MB/s]
# Archive:  resnet-18_80-epochs.zip
#    creating: resnet-18_80-epochs/
#    creating: resnet-18_80-epochs/checkpoints/
#   inflating: resnet-18_80-epochs/checkpoints/config.yaml
#   inflating: resnet-18_80-epochs/checkpoints/model.pth
#   inflating: resnet-18_80-epochs/checkpoints/resnet_simclr.py
#   inflating: resnet-18_80-epochs/events.out.tfevents.1584175972.thallessilva.7272.0
#  resnet-18_80-epochs	   stl10_binary		  'view?usp=sharing'
#  resnet-18_80-epochs.zip   stl10_binary.tar.gz
#  sample_data		   stl10_binary.tar.gz.1

# %%
# !ls
# Out:
#  resnet-18_80-epochs	   stl10_binary		  'view?usp=sharing'
#  resnet-18_80-epochs.zip   stl10_binary.tar.gz
#  sample_data		   stl10_binary.tar.gz.1

# %%
# download and extract stl10
# !wget http://ai.stanford.edu/~acoates/stl10/stl10_binary.tar.gz
# !tar -zxvf stl10_binary.tar.gz
# !ls
# Out:
# --2020-04-25 21:21:34--  http://ai.stanford.edu/~acoates/stl10/stl10_binary.tar.gz
# Resolving ai.stanford.edu (ai.stanford.edu)... 171.64.68.10
# Connecting to ai.stanford.edu (ai.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2640397119 (2.5G) [application/x-gzip]
# Saving to: ‘stl10_binary.tar.gz.2’
#
# stl10_binary.tar.gz 100%[===================>]   2.46G  63.5MB/s    in 34s
#
# 2020-04-25 21:22:07 (75.1 MB/s) - ‘stl10_binary.tar.gz.2’ saved [2640397119/2640397119]
#
# stl10_binary/
# stl10_binary/test_X.bin
# stl10_binary/test_y.bin
# stl10_binary/train_X.bin
# stl10_binary/train_y.bin
# stl10_binary/unlabeled_X.bin
# stl10_binary/class_names.txt
# stl10_binary/fold_indices.txt
#  resnet-18_80-epochs	   stl10_binary		   stl10_binary.tar.gz.2
#  resnet-18_80-epochs.zip   stl10_binary.tar.gz	  'view?usp=sharing'
#  sample_data		   stl10_binary.tar.gz.1

# %%
import torch
import sys
import numpy as np
import os
from sklearn.neighbors import KNeighborsClassifier
import yaml
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn import preprocessing
import importlib.util

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print("Using device:", device)
# Out:
# Using device: cuda

# %%
folder_name = '/data2/meng/SimCLR/SimCLRpytorch/SimCLR/runs/May17_10-41-45_IEEE-8889-1080Ti'
checkpoints_folder = os.path.join(folder_name, 'checkpoints')
config = yaml.load(open(os.path.join(checkpoints_folder, "config.yaml"), "r"))
config
# Out:
# {'batch_size': 512,
#  'epochs': 10,
#  'eval_every_n_epochs': 1,
#  'fine_tune_from': 'None',
#  'log_every_n_steps': 50,
#  'weight_decay': '10e-6',
#  'fp16_precision': False,
#  'loss_type': 'nt_logistic',
#  'model': {'out_dim': 256, 'base_model': 'resnet18'},
#  'dataset': {'s': 1,
#   'input_shape': '(96,96,3)',
#   'num_workers': 0,
#   'valid_size': 0.05},
#  'loss': {'temperature': 0.5, 'use_cosine_similarity': True}}

# %%
checkpoints_folder
# Out:
# 'resnet-18_80-epochs/checkpoints'

# %%
data_root = '/data2/meng/SimCLR/SimCLRpytorch/SimCLR/data/'
def _load_stl10(prefix="train"):
    X_train = np.fromfile(os.path.join(data_root,'./stl10_binary/' + prefix + '_X.bin'), dtype=np.uint8)
    y_train = np.fromfile(os.path.join(data_root,'./stl10_binary/' + prefix + '_y.bin'), dtype=np.uint8)

    X_train = np.reshape(X_train, (-1, 3, 96, 96)) # CWH
    X_train = np.transpose(X_train, (0, 1, 3, 2)) # CHW

    print("{} images".format(prefix))
    print(X_train.shape)
    print(y_train.shape)
    return X_train, y_train - 1

# %%
# load STL-10 train data
X_train, y_train = _load_stl10("train")
# Out:
# train images
# (5000, 3, 96, 96)
# (5000,)

# %%
fig, axs = plt.subplots(nrows=2, ncols=6, constrained_layout=False, figsize=(12,4))

for i, ax in enumerate(axs.flat):
  ax.imshow(X_train[i].transpose(1,2,0))
plt.show()

# %%
# load STL-10 test data
X_test, y_test = _load_stl10("test")
# Out:
# test images
# (8000, 3, 96, 96)
# (8000,)

# %% [markdown]
# ## Test protocol #1 PCA features

# %%
scaler = preprocessing.StandardScaler()
scaler.fit(X_train.reshape((X_train.shape[0],-1)))

pca = PCA(n_components=config['model']['out_dim'])

X_train_pca = pca.fit_transform(scaler.transform(X_train.reshape(X_train.shape[0], -1)))
X_test_pca = pca.transform(scaler.transform(X_test.reshape(X_test.shape[0], -1)))

print("PCA features")
print(X_train_pca.shape)
print(X_test_pca.shape)
# Out:
# PCA features
# (5000, 256)
# (8000, 256)

# %%
def linear_model_eval(X_train, y_train, X_test, y_test):
    
    clf = LogisticRegression(random_state=0, max_iter=1200, solver='lbfgs', C=1.0)
    clf.fit(X_train, y_train)
    print("Logistic Regression feature eval")
    print("Train score:", clf.score(X_train, y_train))
    print("Test score:", clf.score(X_test, y_test))
    
    print("-------------------------------")
    neigh = KNeighborsClassifier(n_neighbors=10)
    neigh.fit(X_train, y_train)
    print("KNN feature eval")
    print("Train score:", neigh.score(X_train, y_train))
    print("Test score:", neigh.score(X_test, y_test))

# %%
linear_model_eval(X_train_pca, y_train, X_test_pca, y_test)

## clean up resources
del X_train_pca
del X_test_pca
# Out:
# Logistic Regression feature eval
# Train score: 0.4862
# Test score: 0.351125
# -------------------------------
# KNN feature eval
# Train score: 0.4052
# Test score: 0.30125

# %% [markdown]
# ## Protocol #2 Logisitc Regression

# %%
# Load the neural net module
net_path = '/data2/meng/SimCLR/SimCLRpytorch/SimCLR/models'
spec = importlib.util.spec_from_file_location("model", os.path.join(net_path, 'resnet_simclr.py'))
resnet_module = importlib.util.module_from_spec(spec)
spec.loader.exec_module(resnet_module)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-29-0289677016bb> in <module>
#       2 spec = importlib.util.spec_from_file_location("model", os.path.join(checkpoints_folder, 'resnet_simclr.py'))
#       3 resnet_module = importlib.util.module_from_spec(spec)
# ----> 4 spec.loader.exec_module(resnet_module)
#
# /data2/wm/anaconda3/lib/python3.7/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /data2/wm/anaconda3/lib/python3.7/importlib/_bootstrap_external.py in get_code(self, fullname)
#
# /data2/wm/anaconda3/lib/python3.7/importlib/_bootstrap_external.py in get_data(self, path)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/data2/meng/SimCLR/SimCLRpytorch/SimCLR/runs/May17_10-41-45_IEEE-8889-1080Ti/checkpoints/resnet_simclr.py'

# %%
model = resnet_module.ResNetSimCLR(**config['model'])
model.eval()

state_dict = torch.load(os.path.join(checkpoints_folder, 'model.pth'), map_location=torch.device('cpu'))
model.load_state_dict(state_dict)
model = model.to(device)
# Out:
# Feature extractor: resnet18
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-27-7884460baf3f> in <module>
#       2 model.eval()
#       3
# ----> 4 state_dict = torch.load(os.path.join(checkpoints_folder, 'model.pth'), map_location=torch.device('cpu'))
#       5 model.load_state_dict(state_dict)
#       6 model = model.to(device)
#
# /data2/wm/anaconda3/lib/python3.7/site-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     417             (sys.version_info[0] == 2 and isinstance(f, unicode)):
#     418         new_fd = True
# --> 419         f = open(f, 'rb')
#     420     elif (sys.version_info[0] == 3 and isinstance(f, pathlib.Path)):
#     421         new_fd = True
#
# FileNotFoundError: [Errno 2] No such file or directory: '/data2/meng/SimCLR/SimCLRpytorch/SimCLR/models/model.pth'

# %%
def next_batch(X, y, batch_size):
    for i in range(0, X.shape[0], batch_size):
        X_batch = torch.tensor(X[i: i+batch_size]) / 255.
        y_batch = torch.tensor(y[i: i+batch_size])
        yield X_batch.to(device), y_batch.to(device)

# %%
X_train_feature = []

for batch_x, batch_y in next_batch(X_train, y_train, batch_size=config['batch_size']):
    features, _ = model(batch_x)
    X_train_feature.extend(features.cpu().detach().numpy())
    
X_train_feature = np.array(X_train_feature)

print("Train features")
print(X_train_feature.shape)

# %%
X_test_feature = []

for batch_x, batch_y in next_batch(X_test, y_test, batch_size=config['batch_size']):
    features, _ = model(batch_x)
    X_test_feature.extend(features.cpu().detach().numpy())
    
X_test_feature = np.array(X_test_feature)

print("Test features")
print(X_test_feature.shape)

# %%
scaler = preprocessing.StandardScaler()
scaler.fit(X_train_feature)

linear_model_eval(scaler.transform(X_train_feature), y_train, scaler.transform(X_test_feature), y_test)

del X_train_feature
del X_test_feature
